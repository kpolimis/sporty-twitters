# %% [markdown]
# ** Analysis **
#
# Here we analyze a file (`matching_scores`) containing the final classifications by anger/hostility (AH), depression (DD), and tension/anxiety(TA).
#
# We compare the output for athletic Twitter users (sporty) versus there matches using a Wilcoxon signed-rank test.

# %%
from numpy import array as npa
def read_results(fname):
    header = None
    results = []
    for line in open(fname, 'rt'):
        parts = line.strip().split(',')
        if not header:
            header = parts
        else:
            results.append(npa([float(x) for x in parts]))
    return header, npa(results)

fields_all, results_all = read_results('matching_scores_with_random.csv')
fields_half, results_half = read_results('halfed_matching_scores')

print 'all labeled tweets: read %d results' % (len(results_all))
print 'half of the labeled tweets: read %d results' % (len(results_half))
# Out:
# all labeled tweets: read 786 results
# half of the labeled tweets: read 840 results

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

def get_labels(fields, random_users=False):
    labels = []
    for i, label in enumerate(['AH', 'DD', 'TA', 'avg']):
        sporty_idx = fields.index('u_' + label)
        nonsporty_idx = fields.index('m_' + label)
        labels_tuple = (label, nonsporty_idx, sporty_idx)
        if random_users:
            random_idx = fields.index('r_' + label)
            labels_tuple = (label, nonsporty_idx, sporty_idx, random_idx)
        labels.append(labels_tuple)
    return labels

def plot_results(labels, results, random_users=False):
    f, axes = plt.subplots(4, 1, sharex=True, figsize=(5,20))
    
    for i, label in enumerate(labels):
        boxplots = [results[:, label[1]], results[:, label[2]]]
        if random_users:
            boxplots.append(results[:, label[3]])
        axes[i].boxplot(boxplots)#, showmeans=True)
        axes[i].set_ylabel('P(' + label[0] + ')')
    xticklabels = ['nosport', 'sport']
    if random_users:
        print random_users
        xticklabels.append('random')
    plt.setp(axes[-1], xticks=[1,2,3], xticklabels=xticklabels)
    plt.setp(axes, yticks=[0, .02, .04, .06, .08, .1])

# classifier trained on all tweets
labels_all = get_labels(fields_all, random_users=True)
plot_results(labels_all, results_all, random_users=True)

# classifier trained on half of the tweets
labels_half = get_labels(fields_half)
plot_results(labels_half, results_half)
# Out:
# True

# %%
import numpy as np
from scipy.stats import wilcoxon

def test_significance(labels, results, idx1=1, idx2=2, diff_legend='(nosport-sport)'): # 1: nosport, 2: sport, 3: random
    print '%10s\t%15s\t%10s\t%10s' % ('label', diff_legend, 'T', 'p')
    for i, label in enumerate(labels):
        left = results[:, label[idx1]]
        right = results[:, label[idx2]]
        wil = wilcoxon(left, right)
        print '%10s\t%15.2e\t%10d\t%10.4f' % (label[0], np.mean(left) - np.mean(right),
                                    wil[0], wil[1])

print 'all the labeled tweets'
test_significance(labels_all, results_all)
test_significance(labels_all, results_all, idx1=3, diff_legend='(random-sport)')
test_significance(labels_all, results_all, idx1=3, idx2=1, diff_legend='(random-nosport)')
print 'half of the labeled tweets'
test_significance(labels_half, results_half)
# Out:
# all the labeled tweets
#      label	(nosport-sport)	         T	         p
#         AH	      -1.82e-04	    150644	    0.5297
#         DD	       1.73e-03	    133254	    0.0008
#         TA	       1.05e-03	    139888	    0.0205
#        avg	       8.65e-04	    140468	    0.0301
#      label	 (random-sport)	         T	         p
#         AH	       5.26e-03	    101701	    0.0000
#         DD	       2.46e-03	    129903	    0.0001
#         TA	       3.21e-03	    125155	    0.0000
#        avg	       3.64e-03	    120045	    0.0000
#      label	(random-nosport)	         T	         p
#         AH	       5.44e-03	    100566	    0.0000
#         DD	       7.35e-04	    139014	    0.0141
#         TA	       2.16e-03	    131592	    0.0003
#        avg	       2.78e-03	    125690	    0.0000
# half of the labeled tweets
#      label	(nosport-sport)	         T	         p
#         AH	      -4.43e-04	    171060	    0.4650
#         DD	       1.23e-03	    159607	    0.0156
#         TA	      -2.86e-05	    173296	    0.6376
#        avg	       2.52e-04	    168699	    0.2607

# %%
# Plot CDFs of samples.
import csv
from collections import Counter
import random
random.seed(1234567)

def read_stats(fname):
    rows = []
    with open(fname, 'rb') as csvfile:
        reader = csv.DictReader(csvfile, delimiter=',')
        return [r for r in reader]

def get_col(stats, label, value):
    if value:
        counts = Counter([x[label] for x in stats])
        return 1. * counts[value] / sum(counts.values())
    else:
        return [float(x[label]) for x in stats]

# Plot boxplots for each stat.
# Not sure what to plot for state...normalized histogram?
def plot_stats(nosport, sport, rnd):
    f, axes = plt.subplots(5, 1, sharex=True, figsize=(5,10))
    labels = [('statuses_count', '# Statuses', None),
              ('followers_count', '# Followers', None),
              ('friends_count', '# Friends', None),
              ('gender', '% Female', 'f'),
              ('state', '% from California', 'California'),
              ]
    for i, (label, pretty_label, value) in enumerate(labels):
        data = [get_col(nosport, label, value),
                get_col(sport, label, value),
                get_col(rnd, label, value)]
        if not value:
            axes[i].boxplot(data, showfliers=False)#, showmeans=True)
        else:
            print data
            axes[i].bar(1 + np.arange(3), data, align='center', width=.2)
        axes[i].set_ylabel(pretty_label)
    # axes[0].legend(loc='lower left')
    # axes[-1].set_xlabel('Rank')
    xticklabels = ['match', 'exercise', 'random']
    xnames = plt.setp(axes[-1], xticks=[1,2,3], xticklabels=xticklabels,
                      xticklabelssize=16)
    plt.savefig('matches.pdf', bbox_inches='tight')


random_stats = read_stats('stats/random_users_stats')
nosport_stats = read_stats('stats/nosport_users_stats')
sport_stats = read_stats('stats/sport_users_stats')
#nosport_stats = random.sample(read_stats('stats/nosport_users_stats'), len(random_stats))
#sport_stats = random.sample(read_stats('stats/sport_users_stats'), len(random_stats))
plot_stats(nosport_stats, sport_stats, random_stats)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-78-52144ab7198a> in <module>()
#      51 #nosport_stats = random.sample(read_stats('stats/nosport_users_stats'), len(random_stats))
#      52 #sport_stats = random.sample(read_stats('stats/sport_users_stats'), len(random_stats))
# ---> 53 plot_stats(nosport_stats, sport_stats, random_stats)
#
# <ipython-input-78-52144ab7198a> in plot_stats(nosport, sport, rnd)
#      42     xticklabels = ['match', 'exercise', 'random']
#      43     xnames = plt.setp(axes[-1], xticks=[1,2,3], xticklabels=xticklabels,
# ---> 44                       xticklabelssize=16)
#      45     plt.savefig('matches.pdf', bbox_inches='tight')
#      46
#
# /Users/awculott/.local/lib/python2.7/site-packages/matplotlib/pyplot.pyc in setp(*args, **kwargs)
#     255 @docstring.copy(_setp)
#     256 def setp(*args, **kwargs):
# --> 257     ret = _setp(*args, **kwargs)
#     258     draw_if_interactive()
#     259     return ret
#
# /Users/awculott/.local/lib/python2.7/site-packages/matplotlib/artist.pyc in setp(obj, *args, **kwargs)
#    1315             s = s.lower()
#    1316             funcName = "set_%s" % s
# -> 1317             func = getattr(o, funcName)
#    1318             ret.extend([func(val)])
#    1319     return [x for x in cbook.flatten(ret)]
#
# AttributeError: 'AxesSubplot' object has no attribute 'set_xticklabelssize'
# [0.25948275862068965, 0.25948275862068965, 0.5189873417721519]
# [0.14913793103448275, 0.14913793103448275, 0.1308016877637131]
